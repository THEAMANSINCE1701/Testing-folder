# %%
import pandas as pd

# %%
df=pd.read_csv("weather_data.csv")

# %%
df
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 3  04-01-2022        8.0     NaN          36
# 4  05-01-2022        NaN   rainy          37
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39

# %%
nf=df.dropna()
nf
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39

# %%
nf=df.dropna(inplace=True)
df
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39

# %%
df1=pd.read_csv("weather_data.csv")
df1
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 3  04-01-2022        8.0     NaN          36
# 4  05-01-2022        NaN   rainy          37
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39

# %%
df1["windspeed"].fillna(130,inplace=True) 
df1
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 3  04-01-2022        8.0   sunny          36
# 4  05-01-2022      130.0   rainy          37
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39

# %%
df1["event"].fillna("sunny",inplace=True)
df1
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 3  04-01-2022        8.0   sunny          36
# 4  05-01-2022      130.0   rainy          37
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39

# %%
df2=pd.read_csv("weather_data.csv")
df2
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 3  04-01-2022        8.0     NaN          36
# 4  05-01-2022        NaN   rainy          37
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39

# %%
x=df["windspeed"].mean()

# %%
x
# Out:
# 5.4

# %%
df2["windspeed"].fillna(x,inplace=True)
df2
# Out:
#           day  windspeed   event  temprature
# 0  01-01-2022        5.0   rainy          33
# 1  02-01-2022        6.0   sunny          34
# 2  03-01-2022        7.0  cloudy          35
# 3  04-01-2022        8.0     NaN          36
# 4  05-01-2022        5.4   rainy          37
# 5  06-01-2022        5.0  cloudy          38
# 6  07-01-2022        4.0   sunny          39
