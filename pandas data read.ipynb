# %%
import pandas as pd

# %%
df=pd.read_csv("indian.csv")

# %%
print(df)
# Out:
#      Rank            City Population(2011) Population(2001)  \
# 0       1          Mumbai       12,442,373       11,978,450
# 1       2           Delhi       11,007,835        9,879,172
# 2       3       Bangalore        8,425,970        4,301,326
# 3       4       Hyderabad        6,809,970        3,637,483
# 4       5       Ahmedabad        5,570,585        3,520,085
# ..    ...             ...              ...              ...
# 317   318          Tezpur          102,505           83,028
# 318   319   Jehanabad[35]          102,456           81,503
# 319   320  Aurangabad[36]          101,520           79,393
# 320   321         Gangtok          100,286           29,354
# 321   322   Vasco Da Gama          100,000                ―
#
#     State or union territory
# 0                Maharashtra
# 1                      Delhi
# 2                  Karnataka
# 3                  Telangana
# 4                    Gujarat
# ..                       ...
# 317                    Assam
# ...

# %%
df.head()
# Out:
#    Rank       City Population(2011) Population(2001) State or union territory
# 0     1     Mumbai       12,442,373       11,978,450              Maharashtra
# 1     2      Delhi       11,007,835        9,879,172                    Delhi
# 2     3  Bangalore        8,425,970        4,301,326                Karnataka
# 3     4  Hyderabad        6,809,970        3,637,483                Telangana
# 4     5  Ahmedabad        5,570,585        3,520,085                  Gujarat

# %%
df["City"]
# Out:
# 0              Mumbai
# 1               Delhi
# 2           Bangalore
# 3           Hyderabad
# 4           Ahmedabad
#             ...
# 317            Tezpur
# 318     Jehanabad[35]
# 319    Aurangabad[36]
# 320           Gangtok
# 321     Vasco Da Gama
# Name: City, Length: 322, dtype: object

# %%
df.loc[0]
# Out:
# Rank                                  1
# City                             Mumbai
# Population(2011)             12,442,373
# Population(2001)             11,978,450
# State or union territory    Maharashtra
# Name: 0, dtype: object

# %%
df[['Population(2001)','Population(2011)']].head(5)
# Out:
#   Population(2001) Population(2011)
# 0       11,978,450       12,442,373
# 1        9,879,172       11,007,835
# 2        4,301,326        8,425,970
# 3        3,637,483        6,809,970
# 4        3,520,085        5,570,585

# %%
df.describe()
# Out:
#              Rank
# count  322.000000
# mean   161.500000
# std     93.097619
# min      1.000000
# 25%     81.250000
# 50%    161.500000
# 75%    241.750000
# max    322.000000

# %%
print(df.to_string())
# Out:
#      Rank                   City Population(2011) Population(2001)        State or union territory
# 0       1                 Mumbai       12,442,373       11,978,450                     Maharashtra
# 1       2                  Delhi       11,007,835        9,879,172                           Delhi
# 2       3              Bangalore        8,425,970        4,301,326                       Karnataka
# 3       4              Hyderabad        6,809,970        3,637,483                       Telangana
# 4       5              Ahmedabad        5,570,585        3,520,085                         Gujarat
# 5       6                Chennai        4,681,087        4,343,645                      Tamil Nadu
# 6       7                Kolkata        4,486,679        4,572,876                     West Bengal
# 7       8                  Surat        4,467,797        2,433,835                         Gujarat
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      322 non-null    int64
#  1   City                      322 non-null    object
#  2   Population(2011)          322 non-null    object
#  3   Population(2001)          322 non-null    object
#  4   State or union territory  322 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 12.7+ KB

# %%
new_df=df.dropna()

# %%
print(new_df.to_string())
# Out:
#      Rank                   City Population(2011) Population(2001)        State or union territory
# 0       1                 Mumbai       12,442,373       11,978,450                     Maharashtra
# 1       2                  Delhi       11,007,835        9,879,172                           Delhi
# 2       3              Bangalore        8,425,970        4,301,326                       Karnataka
# 3       4              Hyderabad        6,809,970        3,637,483                       Telangana
# 4       5              Ahmedabad        5,570,585        3,520,085                         Gujarat
# 5       6                Chennai        4,681,087        4,343,645                      Tamil Nadu
# 6       7                Kolkata        4,486,679        4,572,876                     West Bengal
# 7       8                  Surat        4,467,797        2,433,835                         Gujarat
# ...

# %%
new_df=df.dropna()
print(new_df.to_string())
# Out:
#      Rank                   City Population(2011) Population(2001)        State or union territory
# 0       1                 Mumbai       12,442,373       11,978,450                     Maharashtra
# 1       2                  Delhi       11,007,835        9,879,172                           Delhi
# 2       3              Bangalore        8,425,970        4,301,326                       Karnataka
# 3       4              Hyderabad        6,809,970        3,637,483                       Telangana
# 4       5              Ahmedabad        5,570,585        3,520,085                         Gujarat
# 5       6                Chennai        4,681,087        4,343,645                      Tamil Nadu
# 6       7                Kolkata        4,486,679        4,572,876                     West Bengal
# 7       8                  Surat        4,467,797        2,433,835                         Gujarat
# ...
